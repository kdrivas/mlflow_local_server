# %%
# !pip install awswrangler
# !pip install --upgrade numpy
# !pip install unidecode
# !pip install psycopg2
# !pip install pandarallel
# !pip install shap
# !pip install lightgbm
# !pip install mlflow
# Out:
# ...
# WARNING: You are using pip version 20.3.3; however, version 21.0.1 is available.
# You should consider upgrading via the '/home/ec2-user/anaconda3/envs/python3/bin/python -m pip install --upgrade pip' command.
# ...
# WARNING: You are using pip version 20.3.3; however, version 21.0.1 is available.
# You should consider upgrading via the '/home/ec2-user/anaconda3/envs/python3/bin/python -m pip install --upgrade pip' command.
# ...
# WARNING: You are using pip version 20.3.3; however, version 21.0.1 is available.
# You should consider upgrading via the '/home/ec2-user/anaconda3/envs/python3/bin/python -m pip install --upgrade pip' command.
# ...
# WARNING: You are using pip version 20.3.3; however, version 21.0.1 is available.
# You should consider upgrading via the '/home/ec2-user/anaconda3/envs/python3/bin/python -m pip install --upgrade pip' command.
# ...
# WARNING: You are using pip version 20.3.3; however, version 21.0.1 is available.
# ...

# %%
import pandas as pd
import numpy as np
import awswrangler as wr
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import StratifiedKFold, train_test_split
from sklearn.metrics import roc_auc_score, f1_score, average_precision_score
from sklearn import tree
import pickle
from mlflow.tracking import MlflowClient
import mlflow
from datetime import date
import datetime

# %%
mlflow.set_tracking_uri('http://localhost:5000')

# %%
today = date.today()
day, month, year = today.strftime("%d/%m/%Y").split('/')
period = year + month

# %%
train = wr.s3.read_parquet("s3://rimac-analytics-temporal/individuals/Dante/covid-vida-v2/data/prec/train/data.parquet")
valid = wr.s3.read_parquet("s3://rimac-analytics-temporal/individuals/Dante/covid-vida-v2/data/prec/valid/data.parquet")
test = wr.s3.read_parquet("s3://rimac-analytics-temporal/individuals/Dante/covid-vida-v2/data/prec/test/data.parquet")

# %%
params = {'max_depth': 5, 'min_samples_leaf': 50, 'random_state': 0}

try:
    id_exp = MlflowClient().create_experiment('exp_4')
except:
    id_exp = mlflow.get_experiment_by_name('exp_4').experiment_id

with mlflow.start_run(experiment_id=id_exp) as run:
        
    mlflow.log_metric('train_auc', 0.6)
    mlflow.log_metric('val_auc', 0.3)

    
    mlflow.set_tag('period_train', '202105')
    
    print()
    print(f"artifact_uri={mlflow.get_artifact_uri()}")
    
mlflow.end_run()
# Out:
# ---------------------------------------------------------------------------
# ConnectionRefusedError                    Traceback (most recent call last)
# ~/anaconda3/envs/python3/lib/python3.6/site-packages/urllib3/connection.py in _new_conn(self)
#     169             conn = connection.create_connection(
# --> 170                 (self._dns_host, self.port), self.timeout, **extra_kw
#     171             )
#
# ~/anaconda3/envs/python3/lib/python3.6/site-packages/urllib3/util/connection.py in create_connection(address, timeout, source_address, socket_options)
#      95     if err is not None:
# ---> 96         raise err
#      97
#
# ~/anaconda3/envs/python3/lib/python3.6/site-packages/urllib3/util/connection.py in create_connection(address, timeout, source_address, socket_options)
#      85                 sock.bind(source_address)
# ---> 86             sock.connect(sa)
#      87             return sock
#
# ConnectionRefusedError: [Errno 111] Connection refused
#
# ...
